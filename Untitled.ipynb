# %%
import pandas as pd

# %%
import import_movie_databases

# %%
movies=import_movie_databases.tn_movie_budgets()

# %%
movies.head(5)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# 3        330600000.0     459005868.0     1.403014e+09
# 4        317000000.0     620181382.0     1.316722e+09

# %%
movies.loc[(movies['domestic_gross'] == 0) & (movies['worldwide_gross'] > 0)]
# Out:
#        id  release_date                                           movie  \
# 617    18  Dec 31, 2012  AstÃ©rix et ObÃ©lix: Au service de Sa MajestÃ©
# 619    20  Jan 22, 2019                                       Renegades
# 820    21  Oct 26, 2018                                      Air Strike
# 1325   26  Dec 31, 2012                                      Foodfight!
# 1367   68  Dec 31, 2006                Les BronzÃ©s 3: amis pour la vie
# 1368   69  Dec 31, 2015              Pourquoi j'ai pas mangÃ© mon pÃ¨re
# 1537   38  Apr 16, 2013                              Un monstre Ã Paris
# 1538   39  Jun 21, 2019                                           Kursk
# 1539   40  Nov 11, 2016                USS Indianapolis: Men of Courage
# 1540   41  Dec 31, 2014                      Dragon Nest Warriors' Dawn
# 1583   84  Aug 26, 2008                                Virgin Territory
# 1603    4  Dec 31, 2009                                Obitaemyy ostrov
# ...
