# %%
import pandas as pd
import movie_database_methods as imd
import get_imdb

# %%
imdb = get_imdb.get_imdb()

# %%
tn = imd.tn_movie_budgets()

# %%
combined = imd.movies_combined(tn,imdb)

# %%
combined.head(5)
# Out:
#           tconst  primary_title original_title  start_year  runtime_minutes  \
# 20     tt0249516     Foodfight!     Foodfight!        2012             91.0
# 33     tt0293429  Mortal Kombat  Mortal Kombat        2021              NaN
# 48     tt0337692    On the Road    On the Road        2012            124.0
# 39490  tt2404548    On the Road    On the Road        2011             90.0
# 68078  tt3872966    On the Road    On the Road        2013             87.0
#
#                              genres Action  Crime  Drama Biography  ...  \
# 20      [Action, Animation, Comedy]   True  False  False     False  ...
# 33     [Action, Adventure, Fantasy]   True  False  False     False  ...
# 48      [Adventure, Drama, Romance]  False  False   True     False  ...
# 39490                       [Drama]  False  False   True     False  ...
# 68078                 [Documentary]  False  False  False     False  ...
#
#         News Talk-Show Reality-TV Game-Show  Short  id  release_date  \
# ...

# %%
unique_genres= ['Action','Crime','Drama','Biography','Comedy','Fantasy','Horror','Thriller','Adventure','Animation',
'Documentary','History','Mystery','Sci-Fi','Romance','Family','War','Music','Sport','Western','Musical']

# %%
combined['profit'] = combined.domestic_gross - combined.production_budget

# %% [markdown]
# ### Runtime vs. Profit per Genre

# %%
for genre in unique_genres[0:20]:
   
    combined.loc[combined[genre] == 'True'].plot(kind = 'scatter',x = 'runtime_minutes', 
                                                 xlim = (0,240), y = 'profit', title = genre)

# %%
for genre in unique_genres[20:]:
   
    combined.loc[combined[genre] == 'True'].plot(kind = 'scatter',x = 'runtime_minutes', 
                                                 xlim = (0,240), y = 'profit', title = genre)

# %% [markdown]
# ### Runtime vs. ROI per Genre

# %%
combined['roi'] = combined['profit']/combined['production_budget']

# %%
for genre in unique_genres[0:20]:
   
    combined.loc[combined[genre] == 'True'].plot(kind = 'scatter',x = 'runtime_minutes', 
                                                 xlim = (0,240), y = 'roi', title = genre)

# %%
for genre in unique_genres[20:]:
   
    combined.loc[combined[genre] == 'True'].plot(kind = 'scatter',x = 'runtime_minutes', 
                                                 xlim = (0,240), y = 'roi', title = genre)

# %% [markdown]
# ### Budget vs. Runtime

# %%
combined.plot(kind = 'scatter', x = 'runtime_minutes', xlim = (0,240), y = 'production_budget')

# %% [markdown]
# ### Runtime vs. ROI per Genre

# %%
combined['roi'] = combined['profit']/combined['production_budget']

# %%
for genre in unique_genres[0:20]:
   
    combined.loc[combined[genre] == 'True'].plot(kind = 'scatter',x = 'runtime_minutes', 
                                                 xlim = (0,240), y = 'roi', title = genre)

# %%
for genre in unique_genres[20:]:
   
    combined.loc[combined[genre] == 'True'].plot(kind = 'scatter',x = 'runtime_minutes', 
                                                 xlim = (0,240), y = 'roi', title = genre)
