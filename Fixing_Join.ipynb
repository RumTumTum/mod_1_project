# %% [markdown]
# # Fixing the join

# %% [markdown]
# ## Add year and date to tn

# %%
import pandas as pd
import get_imdb as gi
import movie_database_methods as imd
import matplotlib.pyplot as plt
import seaborn as sns
import pylab
from itertools import product
import numpy as np
# %matplotlib inline
sns.set()

# %%
imdb = gi.get_imdb()

# %%
tn = imd.tn_movie_budgets()
combined = imd.movies_combined(tn,imdb)

# %% [markdown]
# ## Add year and date to imdb

# %% [markdown]
# Not needed. Already done.

# %% [markdown]
# ## View the data to make sure it makes sense

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140736 entries, 0 to 146143
# Data columns (total 33 columns):
# tconst             140736 non-null object
# primary_title      140736 non-null object
# original_title     140734 non-null object
# start_year         140736 non-null int64
# runtime_minutes    112233 non-null float64
# genres             140736 non-null object
# Action             140736 non-null int64
# Crime              140736 non-null int64
# Drama              140736 non-null int64
# Biography          140736 non-null int64
# Comedy             140736 non-null int64
# Fantasy            140736 non-null int64
# Horror             140736 non-null int64
# Thriller           140736 non-null int64
# Adventure          140736 non-null int64
# Animation          140736 non-null int64
# Documentary        140736 non-null int64
# History            140736 non-null int64
# Mystery            140736 non-null int64
# Sci-Fi             140736 non-null int64
# ...

# %% [markdown]
# ## Do the Join again with year

# %% [markdown]
# ### What's the outcome that we want?
# - Combined should not contain any duplicates on ('movie', 'budget')
#  - Does it contain duplicates now?

# %%
combined.groupby(by='primary_title').count()
# Out:
#                                     tconst  original_title  start_year  \
# primary_title
# 10 Cloverfield Lane                      1               1           1
# 10 Days in a Madhouse                    1               1           1
# 12 Rounds                                1               1           1
# 12 Strong                                1               1           1
# 12 Years a Slave                         1               1           1
# 127 Hours                                1               1           1
# 13 Sins                                  1               1           1
# 2 Guns                                   1               1           1
# 21                                       1               1           1
# 21 Jump Street                           1               1           1
# 22 Jump Street                           1               1           1
# 23 Blast                                 1               1           1
# ...

# %%
combined.movie.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-af1d9b5be610> in <module>
# ----> 1 combined.movie.value_counts()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'movie'
